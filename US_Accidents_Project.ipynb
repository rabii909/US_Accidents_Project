# %% [markdown]
# # US Accidents Dataset - Real World Data Engineering Challenge
#
# Student Name: Rabia Farooq
#
# This notebook demonstrates the complete preprocessing pipeline including:
#
# - Data Audit
# - Data Cleaning
# - Feature Engineering
# - Encoding
# - Scaling
# - Validation
# - Final Production Dataset

# %%
import pandas as pd

df = pd.read_csv("data/US_Accidents_March23.csv")

print(df.shape)

df.head()
# Out:
# (7728394, 46)
#     ID   Source  Severity           Start_Time             End_Time  \
# 0  A-1  Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  Distance(mi)  ... Roundabout  \
# 0  39.865147 -84.058723      NaN      NaN          0.01  ...      False
# 1  39.928059 -82.831184      NaN      NaN          0.01  ...      False
# 2  39.063148 -84.032608      NaN      NaN          0.01  ...      False
# 3  39.747753 -84.205582      NaN      NaN          0.01  ...      False
# 4  39.627781 -84.188354      NaN      NaN          0.01  ...      False
#
#   Station   Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# ...

# %% [markdown]
# ## Task 1 - Data Audit
#
# Performed:
#
# - Missing Values Analysis
# - Duplicate Detection
# - Data Types
# - Memory Usage
# - Invalid Coordinates

# %%
df.info()

df.isnull().sum().head()

df.duplicated().sum()

# %% [markdown]
# ## Task 2 - Data Cleaning
#
# Performed:
#
# - Missing Value Imputation
# - Duplicate Removal
# - Datetime Conversion
# - Coordinate Validation
# - Text Normalization
# - Impossible Value Removal

# %%
from clean_data import clean_data

clean_df = clean_data(df)

clean_df.head()

# %% [markdown]
# ## Task 3 - Feature Engineering
#
# Created 30 engineered features including:
#
# - Time Features
# - Weather Features
# - Geographic Features
# - Traffic Features
# - Text Features

# %%
from feature_engineering import feature_engineering

feature_df = feature_engineering(clean_df)

feature_df.head()

# %% [markdown]
# ## Task 4 - Encoding
#
# Applied:
#
# - Label Encoding
# - One-Hot Encoding
# - Frequency Encoding

# %%
from encoding import encode_data

encoded_df = encode_data(feature_df)

encoded_df.head()

# %% [markdown]
# ## Task 5 - Scaling
#
# Compared:
#
# - MinMax Scaling
# - Standard Scaling
# - Robust Scaling
# - Max Absolute Scaling
#
# Final pipeline uses MaxAbsScaler.

# %%
from scaling import scale_data

scaled_df = scale_data(encoded_df)

scaled_df.head()

# %% [markdown]
# ## Task 6 - Validation
#
# The dataset was validated for:
#
# - Missing Values
# - Duplicate Records
# - Dataset Shape

# %%
print(scaled_df.shape)

print(scaled_df.isnull().sum().sum())

print(scaled_df.duplicated().sum())

# %% [markdown]
# # Conclusion
#
# The complete preprocessing pipeline was successfully implemented.
#
# The final dataset is production-ready and includes:
#
# - Cleaning
# - Feature Engineering
# - Encoding
# - Scaling
# - Validation
#
# Output:
# production_ready_US_Accidents.csv
